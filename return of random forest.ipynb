# %%
import os
import matplotlib.image as mpimg 
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import math
from sklearn import tree
from sklearn.model_selection import GridSearchCV
import graphviz

# %%
X = pd.DataFrame(columns = [*range(0,784)])
PATH = os.path.join("C:\\Users\Rahul Singh\\Downloads","data")
train_dir = os.path.join(PATH,'training-images')
test_dir = os.path.join(PATH,'test-images')
def rgb_to_gray (rgb):
    return np.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])
#A list to store lists of flattened image pixels
data = []
label = []
#Starting a for loop to traverse through the image folders, where the folder name is the label of the corresponding image
for file in os.scandir(train_dir):
#Traversing through all the images in each folder
    for image in os.scandir(file):
        img = mpimg.imread(image.path) #using the imread function to convert an image into its pixel values
        fin_img = rgb_to_gray(img)     #calling the earlier defined function to convert RGB to grayscale
        data.append(fin_img.flatten()) #adding all such lists of pixel values in another list, making a list of lists
        label.append(file.name)
for file in os.scandir(test_dir):      #the ab
    for image in os.scandir(file):
        img = mpimg.imread(image.path)
        fin_img = rgb_to_gray(img)
        data.append(fin_img.flatten())
        label.append(file.name)
ddd = np.array(data)  #typecasting the list to numpy array
ddd.shape
#adding the list of pixel values in a proper Dataframe 
for i in range(ddd.shape[1]): 
    X[i] = ddd[:,i]
label = np.array(label)

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(random_state=0)
parameters = {'n_estimators':[10,100,150,200],'min_samples_leaf':[i for i in range(2,25)],'max_depth':[i for i in range(10,35)]+[None],'min_impurity_decrease':[0.001*i for i in range(0,5)] , 'criterion':['gini','entropy']}
clf22 = GridSearchCV(clf,parameters)
clf22.fit(X,label)
clf22.best_estimator_
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=19, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.001, min_impurity_split=None,
#                        min_samples_leaf=2, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)

# %%
dfff = pd.DataFrame(clf22.cv_results_)
dfff.sort_values(by=['mean_test_score'])
# Out:
#        mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 5700        0.037700      0.004695         0.004388        0.001017
# 7080        0.031322      0.000795         0.003789        0.000400
# 11680       0.030524      0.001019         0.003984        0.000011
# 11220       0.029338      0.000486         0.003790        0.000399
# 8000        0.029727      0.000387         0.003390        0.000489
# ...              ...           ...              ...             ...
# 9755        0.572481      0.005247         0.025735        0.000741
# 10215       0.582436      0.015266         0.026142        0.000969
# 4695        1.018211      0.056043         0.048176        0.005500
# 15735       0.622336      0.015244         0.027128        0.001163
# 4235        0.949430      0.056099         0.039890        0.004185
#
#       param_criterion param_max_depth param_min_impurity_decrease  \
# 5700             gini              22                       0.001
# 7080             gini              25                       0.001
# 11680            gini            None                       0.001
# 11220            gini              34                       0.001
# 8000             gini              27                       0.001
# ...               ...             ...                         ...
# 9755             gini              31                       0.001
# 10215            gini              32                       0.001
# 4695             gini              20                       0.001
# 15735         entropy              18                       0.001
# 4235             gini              19                       0.001
#
#       param_min_samples_leaf param_n_estimators  \
# 5700                      24                 10
# 7080                      24                 10
# 11680                     24                 10
# 11220                     24                 10
# 8000                      24                 10
# ...                      ...                ...
# 9755                       2                200
# 10215                      2                200
# 4695                       2                200
# 15735                      2                200
# 4235                       2                200
#
#                                                   params  split0_test_score  \
# 5700   {'criterion': 'gini', 'max_depth': 22, 'min_im...           0.595420
# 7080   {'criterion': 'gini', 'max_depth': 25, 'min_im...           0.595420
# 11680  {'criterion': 'gini', 'max_depth': None, 'min_...           0.595420
# 11220  {'criterion': 'gini', 'max_depth': 34, 'min_im...           0.595420
# 8000   {'criterion': 'gini', 'max_depth': 27, 'min_im...           0.595420
# ...                                                  ...                ...
# 9755   {'criterion': 'gini', 'max_depth': 31, 'min_im...           0.854962
# 10215  {'criterion': 'gini', 'max_depth': 32, 'min_im...           0.854962
# 4695   {'criterion': 'gini', 'max_depth': 20, 'min_im...           0.854962
# 15735  {'criterion': 'entropy', 'max_depth': 18, 'min...           0.877863
# 4235   {'criterion': 'gini', 'max_depth': 19, 'min_im...           0.854962
#
#        split1_test_score  split2_test_score  split3_test_score  \
# 5700            0.671756           0.687023           0.694656
# 7080            0.671756           0.687023           0.694656
# 11680           0.671756           0.687023           0.694656
# 11220           0.671756           0.687023           0.694656
# 8000            0.671756           0.687023           0.694656
# ...                  ...                ...                ...
# 9755            0.824427           0.923664           0.954198
# 10215           0.824427           0.923664           0.954198
# 4695            0.824427           0.923664           0.954198
# 15735           0.824427           0.946565           0.931298
# 4235            0.824427           0.931298           0.954198
#
#        split4_test_score  mean_test_score  std_test_score  rank_test_score
# 5700            0.692308         0.668233        0.037269            23895
# 7080            0.692308         0.668233        0.037269            23895
# 11680           0.692308         0.668233        0.037269            23895
# 11220           0.692308         0.668233        0.037269            23895
# 8000            0.692308         0.668233        0.037269            23895
# ...                  ...              ...             ...              ...
# 9755            0.923077         0.896066        0.048358                3
# 10215           0.923077         0.896066        0.048358                3
# 4695            0.923077         0.896066        0.048358                3
# 15735           0.907692         0.897569        0.043310                2
# 4235            0.923077         0.897592        0.049316                1
#
# [23920 rows x 18 columns]

# %%
final = dfff[['param_criterion','param_n_estimators','param_max_depth','param_min_impurity_decrease','param_min_samples_leaf','mean_test_score']]
final
# Out:
#       param_criterion param_n_estimators param_max_depth  \
# 0                gini                 10              10
# 1                gini                100              10
# 2                gini                150              10
# 3                gini                200              10
# 4                gini                 10              10
# ...               ...                ...             ...
# 23915         entropy                200            None
# 23916         entropy                 10            None
# 23917         entropy                100            None
# 23918         entropy                150            None
# 23919         entropy                200            None
#
#       param_min_impurity_decrease param_min_samples_leaf  mean_test_score
# 0                               0                      2         0.810429
# 1                               0                      2         0.853259
# 2                               0                      2         0.867011
# 3                               0                      2         0.871603
# 4                               0                      3         0.796700
# ...                           ...                    ...              ...
# 23915                       0.004                     23         0.733952
# 23916                       0.004                     24         0.677416
# 23917                       0.004                     24         0.718638
# 23918                       0.004                     24         0.729325
# 23919                       0.004                     24         0.733928
#
# [23920 rows x 6 columns]

# %%
final.sort_values(by=['mean_test_score'], ascending = False).head(10)
# Out:
#       param_criterion param_n_estimators param_max_depth  \
# 4235             gini                200              19
# 15735         entropy                200              18
# 9295             gini                200              30
# 10675            gini                200              33
# 8835             gini                200              29
# 10215            gini                200              32
# 9755             gini                200              31
# 11595            gini                200            None
# 8375             gini                200              28
# 4695             gini                200              20
#
#       param_min_impurity_decrease param_min_samples_leaf  mean_test_score
# 4235                        0.001                      2         0.897592
# 15735                       0.001                      2         0.897569
# 9295                        0.001                      2         0.896066
# 10675                       0.001                      2         0.896066
# 8835                        0.001                      2         0.896066
# 10215                       0.001                      2         0.896066
# 9755                        0.001                      2         0.896066
# 11595                       0.001                      2         0.896066
# 8375                        0.001                      2         0.896066
# 4695                        0.001                      2         0.896066
